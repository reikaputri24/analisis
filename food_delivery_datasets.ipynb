# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv('D:/pandas_journey/mydata/food_delivery_datasets.csv')

# %%
data_df.head(100)
# Out:
#       order_id  voucher_amount                   date_time  eta_seconds  \
# 0   FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1   FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2   FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3   FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4   FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ..         ...             ...                         ...          ...
# 95  FOOD-10441               0  2018-08-12T07:49:24.372746          889
# 96  FOOD-10811               0  2018-09-14T18:51:41.340585           31
# 97  FOOD-10034               0  2018-07-04T14:32:43.483011         1628
# 98  FOOD-10582               0  2018-08-25T20:49:28.694474         1244
# 99  FOOD-10259               0  2018-07-25T17:06:58.342975         2575
#
#     food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# ...

# %%
print(data_df.loc[:, :])
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
print(data_df.describe())
# Out:
#        voucher_amount  eta_seconds     food_price       cust_id      rating  \
# count     1076.000000  1076.000000    1076.000000  1.076000e+03  598.000000
# mean      1053.903346  1632.289033   78041.821561  8.274251e+05    4.946488
# std       3127.726510   948.628732   58512.508208  4.380402e+05    0.295946
# min          0.000000     2.000000   12900.000000  2.289500e+04    1.000000
# 25%          0.000000  1074.750000   38200.000000  3.667210e+05    5.000000
# 50%          0.000000  1605.500000   59200.000000  8.547090e+05    5.000000
# 75%          0.000000  2151.000000  101100.000000  1.230166e+06    5.000000
# max      25000.000000  6082.000000  448500.000000  1.548571e+06    5.000000
#
#        delivery_fee      resto_id    random_id
# count   1076.000000  1.076000e+03  1076.000000
# mean    9252.788104  7.275119e+08     0.498824
# std     6723.595497  8.923529e+07     0.288533
# min        0.000000  2.000006e+08     0.001616
# ...

# %%
print(data_df.loc[:, ['order_id','food_price']])
# Out:
#         order_id  food_price
# 0     FOOD-10455       18900
# 1     FOOD-10985      149000
# 2     FOOD-10911       43800
# 3     FOOD-10932       39900
# 4     FOOD-10961       77700
# ...          ...         ...
# 1071  FOOD-10921      103200
# 1072  FOOD-10265      145700
# 1073  FOOD-10534      177200
# 1074  FOOD-10158       49300
# 1075  FOOD-10770       43000
#
# [1076 rows x 2 columns]

# %%
sort_harga = data_df.sort_values(by="food_price", ascending=False)
print(sort_harga)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 128   FOOD-10212               0  2018-07-21T18:55:34.457186         2723
# 10    FOOD-10386               0  2018-08-06T14:57:55.985171         2673
# 67    FOOD-10633               0  2018-08-31T11:47:18.090120         2474
# 827   FOOD-10565               0  2018-08-24T12:13:00.042608         1936
# 1037  FOOD-10781               0  2018-09-12T17:37:10.213124         2528
# ...          ...             ...                         ...          ...
# 864   FOOD-10439               0  2018-08-11T20:16:56.407026          652
# 851   FOOD-11013               0  2018-09-25T18:40:28.904590         1552
# 858   FOOD-10395               0  2018-08-07T14:52:58.764328          836
# 412   FOOD-10898               0  2018-09-18T13:59:20.321082         1228
# 202   FOOD-10654               0  2018-09-01T17:22:30.082466         1701
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
print(sort_harga.iloc[0])
# Out:
# order_id                          FOOD-10212
# voucher_amount                             0
# date_time         2018-07-21T18:55:34.457186
# eta_seconds                             2723
# food_price                            448500
# cust_id                              1484937
# rating                                     5
# delivery_fee                           13000
# resto_id                           742526785
# status                             Completed
# random_id                           0.469235
# Name: 128, dtype: object
